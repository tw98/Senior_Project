# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# img0=mpimg.imread('results/localizer_early_visual_lam0.1_manilam0.1.jpg')
# img1=mpimg.imread('results/localizer_early_visual_lam1.0_manilam0.1.jpg')
# img2=mpimg.imread('results/localizer_early_visual_lam5.0_manilam0.1.jpg')
# img3=mpimg.imread('results/localizer_early_visual_lam10.0_manilam0.1.jpg')
# labels = ['lambda = 0.1', 'lambda = 1.0', 'lambda = 5.0', 'lambda = 10.0']


img0=mpimg.imread('phate/raw_unnormalized.png')
img1=mpimg.imread('phate/data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam1.0_manilam0.1_phate_shf_2_model_on_test_data_e4000_amlp_PHATE.png')
img2=mpimg.imread('phate/data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam10.0_manilam0.1_phate_shf_model_on_test_data_e4000_amlp_PHATE.png')
img3=mpimg.imread('phate/data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam100.0_manilam0.1_phate_shf_2_model_on_test_data_e4000_amlp_PHATE.png')
labels = ['raw data', 'lambda = 0.1', 'lambda = 10.0', 'lambda = 100.0']
emd = [0.008516956853,0.00842524,0.00787536,0.004901433]


# img0=mpimg.imread('phate/movie_raw_normalized.png')
# img1=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam0.1_manilam0.1_phate_shf_2half_7_model_on_2half_data_e4000_amlp_PHATE.png')
# img2=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam1.0_manilam0.1_phate_shf_2half_1_model_on_2half_data_e4000_amlp_PHATE.png')
# img3=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam5.0_manilam0.1_phate_shf_2half_1_model_on_2half_data_e4000_amlp_PHATE.png')
# labels = ['raw data', 'lambda = 0.1', 'lambda = 1.0', 'lambda = 5.0']
# emd = []

# "raw_normalized.npy", "data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam1.0_manilam0.1_phate_shf_2_model_on_test_data_e4000_amlp_PHATE.npy",
#     "data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam5.0_manilam0.1_phate_shf_model_on_test_data_e4000_amlp_PHATE.npy",
#     "data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam10.0_manilam0.1_phate_shf_model_on_test_data_e4000_amlp_PHATE.npy",
#     "data_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam100.0_manilam0.1_phate_shf_2_model_on_test_data_e4000_amlp_PHATE.npy",

# %%
imgplot = plt.imshow(img0[70:500, 100:630, :])

# %%
fig, axes = plt.subplots(1, 4, figsize=(20,15), sharex=True, sharey=True)
axes[0].imshow(img0[70:500, 100:630, :])
axes[1].imshow(img1[70:500, 100:630, :])
axes[2].imshow(img2[70:500, 100:630, :])
axes[3].imshow(img3[70:500, 100:630, :])
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
plt.subplots_adjust(wspace=0.05, hspace=1)

axes[0].set_title(labels[0], size=16)
axes[1].set_title(labels[1], size=16)
axes[2].set_title(labels[2], size=16)
axes[3].set_title(labels[3], size=16)

axes[0].text(0.5,-0.1, f"EMD: {round(emd[0],6)}", size=16, ha="center", transform=axes[0].transAxes)
axes[1].text(0.5,-0.1, f"EMD: {round(emd[1],6)}", size=16, ha="center", transform=axes[1].transAxes)
axes[2].text(0.5,-0.1, f"EMD: {round(emd[2],6)}", size=16, ha="center", transform=axes[2].transAxes)
axes[3].text(0.5,-0.1, f"EMD: {round(emd[3],6)}", size=16, ha="center", transform=axes[3].transAxes)

plt.savefig('aligned_manifold_localizer.png')

# %%
# img0=mpimg.imread('phate/movie_raw_normalized.png')
# img1=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam0.1_manilam0.1_phate_shf_2half_7_model_on_2half_data_e4000_amlp_PHATE.png')
# img2=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam1.0_manilam0.1_phate_shf_2half_1_model_on_2half_data_e4000_amlp_PHATE.png')
# img3=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam5.0_manilam0.1_phate_shf_2half_1_model_on_2half_data_e4000_amlp_PHATE.png')

# img0=mpimg.imread('phate/movie_raw_normalized.png')
# img1=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam0.1_manilam0.1_phate_shf_2half_7_model_on_2half_data_e4000_amlp_PHATE.png')
# img2=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam1.0_manilam0.1_phate_shf_2half_1_model_on_2half_data_e4000_amlp_PHATE.png')
# img3=mpimg.imread('phate/moviedata_forrest_paper_10pt_hiddendim64_bs64_mlp_md_mse_reg_lam5.0_manilam0.1_phate_shf_2half_1_model_on_2half_data_e4000_amlp_PHATE.png')
# labels = ['raw data', 'lambda = 0.1', 'lambda = 1.0', 'lambda = 5.0']
# emd = []
